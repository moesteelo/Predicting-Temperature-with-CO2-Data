# %%
# Initial imports
import pandas as pd
import hvplot.pandas
from path import Path
import plotly.express as px
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
# Load the dataset.
file_path = "./Data file/Alternative_Fueling_Stations.csv"
crypto_df = pd.read_csv(file_path, index_col=0)
crypto_df.head(10)
# Out:
# /Users/jiajaja/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (9,18,19,23,34,36,37,46,49,52,55,56,60,61,62,63,64,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     Y  OBJECTID FUEL_TYPE_CODE  \
# X
# -86.267021  32.367916         1            CNG
# -84.398837  33.745843         2            CNG
# -84.367461  33.821911         3            CNG
# -84.543822  33.760256         4            CNG
# -95.435385  29.779918         5            CNG
# -94.375338  35.362213         6            CNG
# -71.026549  42.374706         7            CNG
# -71.064352  42.393167         8            CNG
# -73.932309  40.718037         9            CNG
# -73.918344  40.645540        10            CNG
#
#                                                  STATION_NAME  \
# X
# -86.267021               Spire - Montgomery Operations Center
# -84.398837                                PS Energy - Atlanta
# -84.367461       Metropolitan Atlanta Rapid Transit Authority
# -84.543822                              United Parcel Service
# -95.435385  Clean Energy - Texas Department of Transportation
# -94.375338                         Arkansas Oklahoma Gas Corp
# -71.026549         Clean Energy - Logan International Airport
# -71.064352             Clean Energy - Everett - National Grid
# -73.932309          Clean Energy - Greenpoint - National Grid
# -73.918344                           Canarsie - National Grid
#
#                   STREET_ADDRESS  \
# X
# -86.267021      2951 Chestnut St
# -84.398837      340 Whitehall St
# -84.367461   2424 Piedmont Rd NE
# -84.543822  270 Marvin Miller Dr
# -95.435385   7721A Washington St
# -94.375338     2100 S Waldron Rd
# -71.026549   1000 Cottage St Ext
# -71.064352           16 Rover St
# -73.932309       287 Maspeth Ave
# -73.918344       8424 Ditmas Ave
#
#                                       INTERSECTION_DIRECTIONS         CITY  \
# X
# -86.267021                                                NaN   Montgomery
# -84.398837  From I-7585 N, exit 91 to Central Ave, left on...      Atlanta
# -84.367461                                                NaN      Atlanta
# -84.543822                                                NaN      Atlanta
# -95.435385  I-10, Washington Ave exit, 1.5 blocks to the s...      Houston
# -94.375338                                                NaN   Fort Smith
# -71.026549  From Route 1, take the first exit after Callah...  East Boston
# -71.064352  Rt 16, exit to Rt 99, to Dexter St to Rover. O...      Everett
# -73.932309  I-278/Brooklyn Queens Expy, exit onto Vandervo...     Brooklyn
# -73.918344  From Shore Pkwy, take Rockaway Pkwy N, left on...     Brooklyn
#
#            STATE    ZIP  PLUS4  ... HYDROGEN_PRESSURES HYDROGEN_STANDARDS  \
# X                               ...
# -86.267021    AL  36107    NaN  ...                NaN                NaN
# -84.398837    GA  30303    NaN  ...                NaN                NaN
# -84.367461    GA  30324    NaN  ...                NaN                NaN
# -84.543822    GA  30336    NaN  ...                NaN                NaN
# -95.435385    TX  77007    NaN  ...                NaN                NaN
# -94.375338    AR  72903    NaN  ...                NaN                NaN
# -71.026549    MA   2128    NaN  ...                NaN                NaN
# -71.064352    MA   2149    NaN  ...                NaN                NaN
# -73.932309    NY  11211    NaN  ...                NaN                NaN
# -73.918344    NY  11236    NaN  ...                NaN                NaN
#
#            CNG_FILL_TYPE_CODE    CNG_PSI CNG_VEHICLE_CLASS LNG_VEHICLE_CLASS  \
# X
# -86.267021                  B       3600                MD               NaN
# -84.398837                  Q       3600                MD               NaN
# -84.367461                  Q       3000                LD               NaN
# -84.543822                  B       3600                HD               NaN
# -95.435385                  Q  3000 3600                MD               NaN
# -94.375338                  Q       3600                MD               NaN
# -71.026549                  Q  3000 3600                MD               NaN
# -71.064352                  Q  3000 3600                HD               NaN
# -73.932309                  Q  3000 3600                HD               NaN
# -73.918344                  B  3000 3600                MD               NaN
#
#            EV_ON_SITE_RENEWABLE_SOURCE RESTRICTED_ACCESS      LATDD     LONGDD
# X
# -86.267021                         NaN               NaN  32.367916 -86.267021
# -84.398837                         NaN               NaN  33.745843 -84.398837
# -84.367461                         NaN               NaN  33.821911 -84.367461
# -84.543822                         NaN               NaN  33.760256 -84.543822
# -95.435385                         NaN               NaN  29.779918 -95.435385
# -94.375338                         NaN               NaN  35.362213 -94.375338
# -71.026549                         NaN               NaN  42.374706 -71.026549
# -71.064352                         NaN               NaN  42.393167 -71.064352
# -73.932309                         NaN               NaN  40.718037 -73.932309
# -73.918344                         NaN               NaN  40.645540 -73.918344
#
# [10 rows x 69 columns]
