# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import tensorflow as tf

# %%
# Load data
file_path = "usa_co2_temp_1800_2013.csv"
predict_temp_df = pd.read_csv(file_path)
predict_temp_df
# Out:
#            country  year       co2  co2_per_capita  cement_co2  \
# 0    United States  1800     0.253           0.042         NaN
# 1    United States  1801     0.267           0.044         NaN
# 2    United States  1802     0.289           0.046         NaN
# 3    United States  1803     0.297           0.047         NaN
# 4    United States  1804     0.333           0.052         NaN
# ..             ...   ...       ...             ...         ...
# 209  United States  2009  5478.210          17.885      29.615
# 210  United States  2010  5675.786          18.368      31.449
# 211  United States  2011  5540.173          17.781      32.208
# 212  United States  2012  5338.698          17.000      35.270
# 213  United States  2013  5474.257          17.302      36.369
#
#      cement_co2_per_capita  coal_co2  coal_co2_per_capita  flaring_co2  \
# 0                      NaN     0.253                0.042          NaN
# 1                      NaN     0.267                0.044          NaN
# 2                      NaN     0.289                0.046          NaN
# 3                      NaN     0.297                0.047          NaN
# 4                      NaN     0.333                0.052          NaN
# ..                     ...       ...                  ...          ...
# 209                  0.097  1905.943                6.222       39.071
# 210                  0.102  2013.304                6.515       41.343
# 211                  0.103  1903.555                6.109       45.542
# 212                  0.112  1684.037                5.362       48.883
# 213                  0.115  1740.833                5.502       54.647
#
#       gas_co2  ...  co2_per_gdp  methane  methane_per_capita  nitrous_oxide  \
# 0         NaN  ...          NaN      NaN                 NaN            NaN
# 1         NaN  ...          NaN      NaN                 NaN            NaN
# 2         NaN  ...          NaN      NaN                 NaN            NaN
# 3         NaN  ...          NaN      NaN                 NaN            NaN
# 4         NaN  ...          NaN      NaN                 NaN            NaN
# ..        ...  ...          ...      ...                 ...            ...
# 209  1245.742  ...        0.368   649.89               2.122         241.81
# 210  1308.832  ...        0.372   650.38               2.105         247.17
# 211  1327.528  ...        0.357   628.73               2.018         255.55
# 212  1388.255  ...        0.337   618.71               1.970         246.42
# 213  1427.506  ...        0.340   619.02               1.956         247.39
#
#      nitrous_oxide_per_capita  population           gdp  energy_per_gdp  \
# 0                         NaN     6000000           NaN             NaN
# 1                         NaN     6113782           NaN             NaN
# 2                         NaN     6229723           NaN             NaN
# 3                         NaN     6347862           NaN             NaN
# 4                         NaN     6468241           NaN             NaN
# ..                        ...         ...           ...             ...
# 209                     0.789   306307565  1.489429e+13           1.676
# 210                     0.800   309011469  1.527062e+13           1.688
# 211                     0.820   311584051  1.550930e+13           1.650
# 212                     0.785   314043885  1.584964e+13           1.567
# 213                     0.782   316400539  1.610843e+13           1.589
#
#      Avg Temperature  Avg Temperature Uncertainty
# 0          12.377868                     3.205628
# 1          12.681863                     2.895417
# 2          12.859703                     3.065703
# 3          12.692603                     3.065032
# 4          12.576432                     3.379515
# ..               ...                          ...
# 209        11.156327                     0.220114
# 210        11.732877                     0.211351
# 211        11.811093                     0.232825
# 212        12.761842                     0.269340
# 213        13.098420                     0.338102
#
# [214 rows x 24 columns]

# %%
predict_temp_df.tail()
# Out:
#            country  year       co2  co2_per_capita  cement_co2  \
# 209  United States  2009  5478.210          17.885      29.615
# 210  United States  2010  5675.786          18.368      31.449
# 211  United States  2011  5540.173          17.781      32.208
# 212  United States  2012  5338.698          17.000      35.270
# 213  United States  2013  5474.257          17.302      36.369
#
#      cement_co2_per_capita  coal_co2  coal_co2_per_capita  flaring_co2  \
# 209                  0.097  1905.943                6.222       39.071
# 210                  0.102  2013.304                6.515       41.343
# 211                  0.103  1903.555                6.109       45.542
# 212                  0.112  1684.037                5.362       48.883
# 213                  0.115  1740.833                5.502       54.647
#
#       gas_co2  ...  co2_per_gdp  methane  methane_per_capita  nitrous_oxide  \
# 209  1245.742  ...        0.368   649.89               2.122         241.81
# 210  1308.832  ...        0.372   650.38               2.105         247.17
# 211  1327.528  ...        0.357   628.73               2.018         255.55
# 212  1388.255  ...        0.337   618.71               1.970         246.42
# 213  1427.506  ...        0.340   619.02               1.956         247.39
#
#      nitrous_oxide_per_capita  population           gdp  energy_per_gdp  \
# 209                     0.789   306307565  1.489429e+13           1.676
# 210                     0.800   309011469  1.527062e+13           1.688
# 211                     0.820   311584051  1.550930e+13           1.650
# 212                     0.785   314043885  1.584964e+13           1.567
# 213                     0.782   316400539  1.610843e+13           1.589
#
#      Avg Temperature  Avg Temperature Uncertainty
# 209        11.156327                     0.220114
# 210        11.732877                     0.211351
# 211        11.811093                     0.232825
# 212        12.761842                     0.269340
# 213        13.098420                     0.338102
#
# [5 rows x 24 columns]

# %%
predict_temp_df.nunique()
# Out:
# country                          1
# year                           214
# co2                            213
# co2_per_capita                 209
# cement_co2                     102
# cement_co2_per_capita           56
# coal_co2                       213
# coal_co2_per_capita            208
# flaring_co2                     64
# gas_co2                        131
# gas_co2_per_capita             131
# oil_co2                        154
# oil_co2_per_capita             150
# co2_growth_prct                207
# co2_per_gdp                    181
# methane                         24
# methane_per_capita              24
# nitrous_oxide                   24
# nitrous_oxide_per_capita        23
# population                     214
# gdp                            194
# energy_per_gdp                  49
# Avg Temperature                214
# Avg Temperature Uncertainty    214
# dtype: int64

# %%
# Removing the NaN values by replacing the NaN values with the mean average. 
predict_temp_df['flaring_co2'].fillna(predict_temp_df['flaring_co2'].mean(), inplace = True)
predict_temp_df['cement_co2'].fillna(predict_temp_df['cement_co2'].mean(), inplace = True)
predict_temp_df['cement_co2_per_capita'].fillna(predict_temp_df['cement_co2_per_capita'].mean(), inplace = True)
predict_temp_df['gas_co2'].fillna(predict_temp_df['gas_co2'].mean(), inplace = True)
predict_temp_df['gas_co2_per_capita'].fillna(predict_temp_df['gas_co2_per_capita'].mean(), inplace = True)
predict_temp_df['oil_co2'].fillna(predict_temp_df['oil_co2'].mean(), inplace = True)
predict_temp_df['oil_co2_per_capita'].fillna(predict_temp_df['oil_co2_per_capita'].mean(), inplace = True)
predict_temp_df['co2_per_gdp'].fillna(predict_temp_df['co2_per_gdp'].mean(), inplace = True)
predict_temp_df['methane'].fillna(predict_temp_df['methane'].mean(), inplace = True)
predict_temp_df['methane_per_capita'].fillna(predict_temp_df['methane_per_capita'].mean(), inplace = True)
predict_temp_df['nitrous_oxide'].fillna(predict_temp_df['nitrous_oxide'].mean(), inplace = True)
predict_temp_df['nitrous_oxide_per_capita'].fillna(predict_temp_df['nitrous_oxide_per_capita'].mean(), inplace = True)
predict_temp_df['gdp'].fillna(predict_temp_df['gdp'].mean(), inplace = True)
predict_temp_df['energy_per_gdp'].fillna(predict_temp_df['energy_per_gdp'].mean(), inplace = True)
predict_temp_df['co2_growth_prct'].fillna(predict_temp_df['co2_growth_prct'].mean(), inplace = True)

predict_temp_df.isnull().sum()
# Out:
# country                        0
# year                           0
# co2                            0
# co2_per_capita                 0
# cement_co2                     0
# cement_co2_per_capita          0
# coal_co2                       0
# coal_co2_per_capita            0
# flaring_co2                    0
# gas_co2                        0
# gas_co2_per_capita             0
# oil_co2                        0
# oil_co2_per_capita             0
# co2_growth_prct                0
# co2_per_gdp                    0
# methane                        0
# methane_per_capita             0
# nitrous_oxide                  0
# nitrous_oxide_per_capita       0
# population                     0
# gdp                            0
# energy_per_gdp                 0
# Avg Temperature                0
# Avg Temperature Uncertainty    0
# dtype: int64

# %%
predict_temp_df.dtypes
# Out:
# country                         object
# year                             int64
# co2                            float64
# co2_per_capita                 float64
# cement_co2                     float64
# cement_co2_per_capita          float64
# coal_co2                       float64
# coal_co2_per_capita            float64
# flaring_co2                    float64
# gas_co2                        float64
# gas_co2_per_capita             float64
# oil_co2                        float64
# oil_co2_per_capita             float64
# co2_growth_prct                float64
# co2_per_gdp                    float64
# methane                        float64
# methane_per_capita             float64
# nitrous_oxide                  float64
# nitrous_oxide_per_capita       float64
# population                       int64
# gdp                            float64
# energy_per_gdp                 float64
# Avg Temperature                float64
# Avg Temperature Uncertainty    float64
# dtype: object

# %%
# Drop the non-beneficial ID columns
predict_temp_df = predict_temp_df.drop(columns=["country", "year"], axis=1)

# %%
# Renaming the DataFrame to help fit column name in the Y and X features data
predict_temp_df.rename(columns={'Avg Temperature': 'AvgTemperature'}, inplace=True)

# %%
predict_temp_df['AvgTemperature'] = predict_temp_df['AvgTemperature'].astype('int64')

# %%
# Remove Avg Temperature outcome target from features data
y = predict_temp_df.AvgTemperature
X = predict_temp_df.drop(columns="AvgTemperature")

# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
predict_temp_df
# Out:
#           co2  co2_per_capita  cement_co2  cement_co2_per_capita  coal_co2  \
# 0       0.253           0.042   18.398612               0.085731     0.253
# 1       0.267           0.044   18.398612               0.085731     0.267
# 2       0.289           0.046   18.398612               0.085731     0.289
# 3       0.297           0.047   18.398612               0.085731     0.297
# 4       0.333           0.052   18.398612               0.085731     0.333
# ..        ...             ...         ...                    ...       ...
# 209  5478.210          17.885   29.615000               0.097000  1905.943
# 210  5675.786          18.368   31.449000               0.102000  2013.304
# 211  5540.173          17.781   32.208000               0.103000  1903.555
# 212  5338.698          17.000   35.270000               0.112000  1684.037
# 213  5474.257          17.302   36.369000               0.115000  1740.833
#
#      coal_co2_per_capita  flaring_co2      gas_co2  gas_co2_per_capita  \
# 0                  0.042    27.881063   497.198833            2.186538
# 1                  0.044    27.881063   497.198833            2.186538
# 2                  0.046    27.881063   497.198833            2.186538
# 3                  0.047    27.881063   497.198833            2.186538
# 4                  0.052    27.881063   497.198833            2.186538
# ..                   ...          ...          ...                 ...
# 209                6.222    39.071000  1245.742000            4.067000
# 210                6.515    41.343000  1308.832000            4.236000
# 211                6.109    45.542000  1327.528000            4.261000
# 212                5.362    48.883000  1388.255000            4.421000
# 213                5.502    54.647000  1427.506000            4.512000
#
#          oil_co2  ...  co2_per_gdp   methane  methane_per_capita  \
# 0     925.551682  ...     0.718742  688.9625              2.4435
# 1     925.551682  ...     0.718742  688.9625              2.4435
# 2     925.551682  ...     0.718742  688.9625              2.4435
# 3     925.551682  ...     0.718742  688.9625              2.4435
# 4     925.551682  ...     0.718742  688.9625              2.4435
# ..           ...  ...          ...       ...                 ...
# 209  2233.033000  ...     0.368000  649.8900              2.1220
# 210  2250.504000  ...     0.372000  650.3800              2.1050
# 211  2201.747000  ...     0.357000  628.7300              2.0180
# 212  2152.124000  ...     0.337000  618.7100              1.9700
# 213  2184.125000  ...     0.340000  619.0200              1.9560
#
#      nitrous_oxide  nitrous_oxide_per_capita  population           gdp  \
# 0       259.413333                  0.916625     6000000  3.055051e+12
# 1       259.413333                  0.916625     6113782  3.055051e+12
# 2       259.413333                  0.916625     6229723  3.055051e+12
# 3       259.413333                  0.916625     6347862  3.055051e+12
# 4       259.413333                  0.916625     6468241  3.055051e+12
# ..             ...                       ...         ...           ...
# 209     241.810000                  0.789000   306307565  1.489429e+13
# 210     247.170000                  0.800000   309011469  1.527062e+13
# 211     255.550000                  0.820000   311584051  1.550930e+13
# 212     246.420000                  0.785000   314043885  1.584964e+13
# 213     247.390000                  0.782000   316400539  1.610843e+13
#
#      energy_per_gdp  AvgTemperature  Avg Temperature Uncertainty
# 0          2.602592              12                     3.205628
# 1          2.602592              12                     2.895417
# 2          2.602592              12                     3.065703
# 3          2.602592              12                     3.065032
# 4          2.602592              12                     3.379515
# ..              ...             ...                          ...
# 209        1.676000              11                     0.220114
# 210        1.688000              11                     0.211351
# 211        1.650000              11                     0.232825
# 212        1.567000              12                     0.269340
# 213        1.589000              13                     0.338102
#
# [214 rows x 22 columns]

# %% [markdown]
# # Using Logistic Regression Model

# %%
# Preprocess numerical data for neural network

# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the logistic regression model
log_classifier = LogisticRegression(solver="lbfgs",max_iter=200)

# Train the model
log_classifier.fit(X_train,y_train)

# Evaluate the model
y_pred = log_classifier.predict(X_test)
print(f" Logistic regression model accuracy: {accuracy_score(y_test,y_pred):.3f}")
# Out:
#  Logistic regression model accuracy: 0.278

# %%
# Define the basic neural network model
nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=80, input_dim=21, activation="relu"))

# Second hidden layer
nn_model.add(tf.keras.layers.Dense(units=50, activation="sigmoid"))


# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Compile the Sequential model together and customize metrics
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn_model.fit(X_train_scaled, y_train, epochs=100)

# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 3ms/step - loss: 0.3374 - accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 9ms/step - loss: -5.9759 - accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 4ms/step - loss: -12.1831 - accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 6ms/step - loss: -18.4839 - accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 11ms/step - loss: -24.8901 - accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: -32.4741 - accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 6ms/step - loss: -41.1937 - accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 5ms/step - loss: -51.3193 - accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 5ms/step - loss: -63.6983 - accuracy: 0.0000e+00
# Epoch 10/100
# 5/5 [==============================] - 0s 6ms/step - loss: -78.1470 - accuracy: 0.0000e+00
# Epoch 11/100
# 5/5 [==============================] - 0s 6ms/step - loss: -95.2431 - accuracy: 0.0000e+00
# Epoch 12/100
# 5/5 [==============================] - 0s 4ms/step - loss: -115.0957 - accuracy: 0.0000e+00
# Epoch 13/100
# 5/5 [==============================] - 0s 10ms/step - loss: -139.0002 - accuracy: 0.0000e+00
# Epoch 14/100
# 5/5 [==============================] - 0s 6ms/step - loss: -167.4690 - accuracy: 0.0000e+00
# Epoch 15/100
# 5/5 [==============================] - 0s 8ms/step - loss: -201.1634 - accuracy: 0.0000e+00
# Epoch 16/100
# 5/5 [==============================] - 0s 16ms/step - loss: -238.7333 - accuracy: 0.0000e+00
# Epoch 17/100
# 5/5 [==============================] - 0s 9ms/step - loss: -283.4216 - accuracy: 0.0000e+00
# Epoch 18/100
# 5/5 [==============================] - 0s 5ms/step - loss: -333.1376 - accuracy: 0.0000e+00
# Epoch 19/100
# 5/5 [==============================] - 0s 4ms/step - loss
# Epoch 69/100
# 5/5 [==============================] - 0s 6ms/step - loss: -24176.8438 - accuracy: 0.0000e+00
# Epoch 70/100
# 5/5 [==============================] - 0s 4ms/step - loss: -25300.6094 - accuracy: 0.0000e+00
# Epoch 71/100
# 5/5 [==============================] - 0s 8ms/step - loss: -26481.9434 - accuracy: 0.0000e+00
# Epoch 72/100
# 5/5 [==============================] - 0s 6ms/step - loss: -27636.5156 - accuracy: 0.0000e+00
# Epoch 73/100
# 5/5 [==============================] - 0s 7ms/step - loss: -28896.1504 - accuracy: 0.0000e+00
# Epoch 74/100
# 5/5 [==============================] - 0s 6ms/step - loss: -30132.9570 - accuracy: 0.0000e+00
# Epoch 75/100
# 5/5 [==============================] - 0s 4ms/step - loss: -31444.3965 - accuracy: 0.0000e+00
# Epoch 76/100
# 5/5 [==============================] - 0s 4ms/step - loss: -32809.3906 - accuracy: 0.0000e+00
# Epoch 77/100
# 5/5 [==============================] - 0s 6ms/step - loss: -34186.1445 - accuracy: 0.0000e+00
# Epoch 78/100
# 5/5 [==============================] - 0s 6ms/step - loss: -35562.7734 - accuracy: 0.0000e+00
# Epoch 79/100
# 5/5 [==============================] - 0s 4ms/step - loss: -37008.4570 - accuracy: 0.0000e+00
# Epoch 80/100
# 5/5 [==============================] - 0s 5ms/step - loss: -38505.4922 - accuracy: 0.0000e+00
# Epoch 81/100
# 5/5 [==============================] - 0s 4ms/step - loss: -39992.4688 - accuracy: 0.0000e+00
# Epoch 82/100
# 5/5 [==============================] - 0s 4ms/step - loss: -41615.2148 - accuracy: 0.0000e+00
# Epoch 83/100
# 5/5 [==============================] - 0s 4ms/step - loss: -43154.0977 - accuracy: 0.0000e+00
# Epoch 84/100
# 5/5 [==============================] - 0s 5ms/step - loss: -44825.8320 - accuracy: 0.0000e+00
# Epoch 85/100
# 5/5 [==============================] - 0s 6ms/step - loss: -46496.7969 - accuracy: 0.0000e+00
# Epoch 86/100
# 5/5 [==============================] - 0s 4ms/step - loss: -48175.0703 - accuracy: 0.0000e+00
# Epoch 87/100
# 5/5 [==============================] - 0s 4ms/step - loss: -49951.6797 - accuracy: 0.0000e+00
# Epoch 88/100
# 5/5 [==============================] - 0s 5ms/step - loss: -51799.5820 - accuracy: 0.0000e+00
# Epoch 89/100
# 5/5 [==============================] - 0s 5ms/step - loss: -53582.8633 - accuracy: 0.0000e+00
# Epoch 90/100
# 5/5 [==============================] - 0s 5ms/step - loss: -55458.3984 - accuracy: 0.0000e+00
# Epoch 91/100
# 5/5 [==============================] - 0s 5ms/step - loss: -57382.0703 - accuracy: 0.0000e+00
# Epoch 92/100
# 5/5 [==============================] - 0s 11ms/step - loss: -59384.7305 - accuracy: 0.0000e+00
# Epoch 93/100
# 5/5 [==============================] - 0s 4ms/step - loss: -61372.8438 - accuracy: 0.0000e+00
# Epoch 94/100
# 5/5 [==============================] - 0s 5ms/step - loss: -63418.2305 - accuracy: 0.0000e+00
# Epoch 95/100
# 5/5 [==============================] - 0s 7ms/step - loss: -65505.5859 - accuracy: 0.0000e+00
# Epoch 96/100
# 5/5 [==============================] - 0s 4ms/step - loss: -67716.6172 - accuracy: 0.0000e+00
# Epoch 97/100
# 5/5 [==============================] - 0s 4ms/step - loss: -69881.2266 - accuracy: 0.0000e+00
# Epoch 98/100
# 5/5 [==============================] - 0s 4ms/step - loss: -72044.9375 - accuracy: 0.0000e+00
# Epoch 99/100
# 5/5 [==============================] - 0s 9ms/step - loss: -74348.4609 - accuracy: 0.0000e+00
# Epoch 100/100
# 5/5 [==============================] - 0s 5ms/step - loss: -76663.5156 - accuracy: 0.0000e+00
# 2/2 - 0s - loss: -8.1543e+04 - accuracy: 0.0000e+00 - 129ms/epoch - 64ms/step
# Loss: -81543.03125, Accuracy: 0.0

# %% [markdown]
# # Using Deep Learning Model

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
X_train
# Out:
#           co2  co2_per_capita  cement_co2  cement_co2_per_capita  coal_co2  \
# 138  1515.693          11.136    9.182000               0.068000   906.794
# 52     26.791           1.068   18.398612               0.085731    26.791
# 66     59.232           1.600   18.398612               0.085731    57.763
# 26      1.315           0.111   18.398612               0.085731     1.315
# 61     45.679           1.393   18.398612               0.085731    44.818
# ..        ...             ...         ...                    ...       ...
# 67     72.866           1.922   18.398612               0.085731    71.499
# 192  5167.481          20.108   32.993000               0.128000  1850.697
# 117  1670.971          15.673    0.008000               0.000000  1481.645
# 47     15.070           0.699   18.398612               0.085731    15.070
# 172  4572.791          21.441   36.299000               0.170000  1124.841
#
#      coal_co2_per_capita  flaring_co2      gas_co2  gas_co2_per_capita  \
# 138                6.662    27.881063   115.320000            0.847000
# 52                 1.068    27.881063   497.198833            2.186538
# 66                 1.560    27.881063   497.198833            2.186538
# 26                 0.111    27.881063   497.198833            2.186538
# 61                 1.367    27.881063   497.198833            2.186538
# ..                   ...          ...          ...                 ...
# 67                 1.886    27.881063   497.198833            2.186538
# 192                7.201    40.963000  1091.238000            4.246000
# 117               13.897    27.881063    38.882000            0.365000
# 47                 0.699    27.881063   497.198833            2.186538
# 172                5.274    13.308000  1115.673000            5.231000
#
#          oil_co2  ...  co2_growth_prct  co2_per_gdp   methane  \
# 138   482.196000  ...           -15.44        1.104  688.9625
# 52    925.551682  ...             8.76        0.267  688.9625
# 66      1.469000  ...             0.70        0.349  688.9625
# 26    925.551682  ...            15.81        0.038  688.9625
# 61      0.861000  ...            -3.71        0.324  688.9625
# ..           ...  ...              ...          ...       ...
# 67      1.367000  ...            23.02        0.407  688.9625
# 192  2128.090000  ...             2.17        0.540  769.5900
# 117   147.941000  ...            10.01        1.648  688.9625
# 47    925.551682  ...            18.56        0.192  688.9625
# 172  2269.174000  ...             4.75        0.857  688.9625
#
#      methane_per_capita  nitrous_oxide  nitrous_oxide_per_capita  population  \
# 138              2.4435     259.413333                  0.916625   136108915
# 52               2.4435     259.413333                  0.916625    25092277
# 66               2.4435     259.413333                  0.916625    37017769
# 26               2.4435     259.413333                  0.916625    11834416
# 61               2.4435     259.413333                  0.916625    32787298
# ..                  ...            ...                       ...         ...
# 67               2.4435     259.413333                  0.916625    37917653
# 192              2.9950     257.860000                  1.003000   256990608
# 117              2.4435     259.413333                  0.916625   106614820
# 47               2.4435     259.413333                  0.916625    21560737
# 172              2.4435     259.413333                  0.916625   213269805
#
#               gdp  energy_per_gdp  Avg Temperature Uncertainty
# 138  1.373408e+12        2.602592                     0.227255
# 52   1.001978e+11        2.602592                     1.821508
# 66   1.695929e+11        2.602592                     1.238647
# 26   3.480963e+10        2.602592                     2.601358
# 61   1.409043e+11        2.602592                     1.405408
# ..            ...             ...                          ...
# 67   1.791725e+11        2.602592                     1.467890
# 192  9.572148e+12        2.383000                     0.247250
# 117  1.014196e+12        2.602592                     0.381123
# 47   7.862561e+10        2.602592                     2.324403
# 172  5.334297e+12        3.704000                     0.226680
#
# [160 rows x 21 columns]

# %%
# Define the model - deep neural net
number_input_features = (X_train)
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=21, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 80)                1760
#
#  dense_36 (Dense)            (None, 50)                4050
#
#  dense_37 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 5,861
# Trainable params: 5,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 4ms/step - loss: -331335499776.0000 - accuracy: 0.0000e+00
# Epoch 2/100
# 5/5 [==============================] - 0s 10ms/step - loss: -3514205470720.0000 - accuracy: 0.0000e+00
# Epoch 3/100
# 5/5 [==============================] - 0s 10ms/step - loss: -6246571180032.0000 - accuracy: 0.0000e+00
# Epoch 4/100
# 5/5 [==============================] - 0s 9ms/step - loss: -8709090574336.0000 - accuracy: 0.0000e+00
# Epoch 5/100
# 5/5 [==============================] - 0s 8ms/step - loss: -11561425960960.0000 - accuracy: 0.0000e+00
# Epoch 6/100
# 5/5 [==============================] - 0s 6ms/step - loss: -14385315577856.0000 - accuracy: 0.0000e+00
# Epoch 7/100
# 5/5 [==============================] - 0s 6ms/step - loss: -17799112032256.0000 - accuracy: 0.0000e+00
# Epoch 8/100
# 5/5 [==============================] - 0s 4ms/step - loss: -21445279219712.0000 - accuracy: 0.0000e+00
# Epoch 9/100
# 5/5 [==============================] - 0s 6ms/step - loss: -25706832592896.0000 - accuracy: 0.0000e+00
# Epoch 10/100
# 5/5 [==============================] - 0s 16ms/step - loss: -30589558194176.0000 - accuracy: 0.0000e+00
# Epoch 11/100
# 5/5 [==============================] - 0s 8ms/step - loss: -35612212068352.0000 - accuracy: 0.0000e+00
# Epoch 12/100
# 5/5 [==============================] - 0s 9ms/step - loss: -42109562257408.0000 - accuracy: 0.0000e+00
# Epoch 13/100
# 5/5 [==============================] - 0s 10ms/step - loss: -48643247702016.0000 - accuracy: 0.0000e+00
# Epoch 14/100
# 5/5 [==============================] - 0s 5ms/step - loss: -56549028397056.0000 - accuracy: 0.0000e+00
# Epoch 15/100
# 5/5 [==============================] - 0s 7ms/step - loss: -64910755102720.0000 - accuracy: 0.0000e+00
# Epoch 16/100
# 5/5 [==============================] - 0s 7ms/step - loss: -75310917746688.0000 - accuracy: 0.0000e+00
# Epoch 17/100
# 5/5 [==============================] - 0s 5ms/step - loss: -86746108788736.0000 - accuracy: 0.0000e+00
# Epoch 18/100
# 5/5 [==============================] - 0s 8ms/step - loss: -99581652107264.0000 - accuracy: 0.0000e+00
# Epoch 19/100
# 5/5 [==============================] - 0s 7ms/step - loss: -113018457292800.0000 - accuracy: 0.0000e+00
# Epoch 20/100
# 5/5 [==============================] - 0s 10ms/step - loss: -129056385269760.0000 - accuracy: 0.0000e+00
# Epoch 21/100
# 5/5 [==============================] - 0s 7ms/step - loss: -146930998968320.0000 - accuracy: 0.0000e+00
# Epoch 22/100
# 5/5 [==============================] - 0s 6ms/step - loss: -166553647579136.0000 - accuracy: 0.0000e+00
# Epoch 23/100
# 5/5 [==============================] - 0s 7ms/step - loss: -187006315397120.0000 - accuracy: 0.0000e+00
# Epoch 24/100
# 5/5 [==============================] - 0s 6ms/step - loss: -211688989130752.0000 - accuracy: 0.0000e+00
# Epoch 25/100
# 5/5 [==============================] - 0s 5ms/step - loss: -237729560395776.0000 - accuracy: 0.0000e+00
# Epoch 26/100
# 5/5 [==============================] - 0s 7ms/step - loss: -265767526334464.0000 - accuracy: 0.0000e+00
# Epoch 27/100
# 5/5 [==============================] - 0s 7ms/step - loss: -298460028862464.0000 - accuracy: 0.0000e+00
# Epoch 28/100
# 5/5 [==============================] - 0s 5ms/step - loss: -330770698731520.0000 - accuracy: 0.0000e+00
# Epoch 29/100
# 5/5 [==============================] - 0s 4ms/step - loss: -367960485003264.0000 - accuracy: 0.0000e+00
# Epoch 30/100
# 5/5 [==============================] - 0s 6ms/step - loss: -408959773048832.0000 - accuracy: 0.0000e+00
# Epoch 31/100
# 5/5 [==============================] - 0s 3ms/step - loss: -450159649488896.0000 - accuracy: 0.0000e+00
# Epoch 32/100
# 5/5 [==============================] - 0s 5ms/step - loss: -493293167181824.0000 - accuracy: 0.0000e+00
# Epoch 33/100
# 5/5 [==============================] - 0s 5ms/step - loss: -545864674181120.0000 - accuracy: 0.0000e+00
# Epoch 34/100
# 5/5 [==============================] - 0s 10ms/step - loss: -597019982823424.0000 - accuracy: 0.0000e+00
# Epoch 35/100
# 5/5 [==============================] - 0s 5ms/step - loss: -651714310963200.0000 - accuracy: 0.0000e+00
# Epoch 36/100
# 5/5 [==============================] - 0s 8ms/step - loss: -711899150811136.0000 - accuracy: 0.0000e+00
# Epoch 37/100
# 5/5 [==============================] - 0s 6ms/step - loss: -779786880286720.0000 - accuracy: 0.0000e+00
# Epoch 38/100
# 5/5 [==============================] - 0s 7ms/step - loss: -848444079996928.0000 - accuracy: 0.0000e+00
# Epoch 39/100
# 5/5 [==============================] - 0s 6ms/step - loss: -915209950593024.0000 - accuracy: 0.0000e+00
# Epoch 40/100
# 5/5 [==============================] - 0s 5ms/step - loss: -991125309489152.0000 - accuracy: 0.0000e+00
# Epoch 41/100
# 5/5 [==============================] - 0s 12ms/step - loss: -1070895133097984.0000 - accuracy: 0.0000e+00
# Epoch 42/100
# 5/5 [==============================] - 0s 6ms/step - loss: -1160802153267200.0000 - accuracy: 0.0000e+00
# Epoch 43/100
# 5/5 [==============================] - 0s 4ms/step - loss: -1244501536407552.0000 - accuracy: 0.0000e+00
# Epoch 44/100
# 5/5 [==============================] - 0s 5ms/step - loss: -1345177046220800.0000 - accuracy: 0.0000e+00
# Epoch 45/100
# 5/5 [==============================] - 0s 5ms/step - loss: -1440719533244416.0000 - accuracy: 0.0000e+00
# Epoch 46/100
# 5/5 [==============================] - 0s 5ms/step - loss: -1547023060828160.0000 - accuracy: 0.0000e+00
# Epoch 47/100
# 5/5 [==============================] - 0s 6ms/step - loss: -1658370893283328.0000 - accuracy: 0.0000e+00
# Epoch 48/100
# 5/5 [==============================] - 0s 7ms/step - loss: -1779866928152576.0000 - accuracy: 0.0000e+00
# Epoch 49/100
# 5/5 [==============================] - 0s 5ms/step - loss: -1892152942526464.0000 - accuracy: 0.0000e+00
# Epoch 50/100
# 5/5 [==============================] - 0s 5ms/step - loss: -2020224572325888.0000 - accuracy: 0.0000e+00
# Epoch 51/100
# 5/5 [==============================] - 0s 5ms/step - loss: -2144603603992576.0000 - accuracy: 0.0000e+00
# Epoch 52/100
# 5/5 [==============================] - 0s 5ms/step - loss: -2287210745298944.0000 - accuracy: 0.0000e+00
# Epoch 53/100
# 5/5 [==============================] - 0s 6ms/step - loss: -2428892589588480.0000 - accuracy: 0.0000e+00
# Epoch 54/100
# 5/5 [==============================] - 0s 13ms/step - loss: -2578672594714624.0000 - accuracy: 0.0000e+00
# Epoch 55/100
# 5/5 [==============================] - 0s 3ms/step - loss