# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf

veh_petrol_df = pd.read_csv('Alternative_Fueling_Stations.csv')
veh_petrol_df
# Out:
# /Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (9,18,19,23,34,36,37,46,49,52,55,56,60,61,62,63,64,65) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                X          Y  OBJECTID FUEL_TYPE_CODE  \
# 0     -86.267021  32.367916         1            CNG
# 1     -84.398837  33.745843         2            CNG
# 2     -84.367461  33.821911         3            CNG
# 3     -84.543822  33.760256         4            CNG
# 4     -95.435385  29.779918         5            CNG
# ...          ...        ...       ...            ...
# 59922 -90.718917  41.439327     59923             BD
# 59923 -90.435422  40.663268     59924             BD
# 59924 -88.860665  42.274948     59925             BD
# 59925 -88.723836  41.923353     59926             BD
# 59926 -89.630156  42.275947     59927             BD
#
# ...

# %%
veh_petrol_df.dtypes
# Out:
# X                              float64
# Y                              float64
# OBJECTID                         int64
# FUEL_TYPE_CODE                  object
# STATION_NAME                    object
#                                 ...
# LNG_VEHICLE_CLASS               object
# EV_ON_SITE_RENEWABLE_SOURCE     object
# RESTRICTED_ACCESS              float64
# LATDD                          float64
# LONGDD                         float64
# Length: 70, dtype: object

# %%
# Dropping Columns that have more than 90% Nan Values
veh_petrol_df.dropna(thresh=len(veh_petrol_df)*0.9, axis='columns')
# Out:
#                X          Y  OBJECTID FUEL_TYPE_CODE  \
# 0     -86.267021  32.367916         1            CNG
# 1     -84.398837  33.745843         2            CNG
# 2     -84.367461  33.821911         3            CNG
# 3     -84.543822  33.760256         4            CNG
# 4     -95.435385  29.779918         5            CNG
# ...          ...        ...       ...            ...
# 59922 -90.718917  41.439327     59923             BD
# 59923 -90.435422  40.663268     59924             BD
# 59924 -88.860665  42.274948     59925             BD
# 59925 -88.723836  41.923353     59926             BD
# 59926 -89.630156  42.275947     59927             BD
#
#                                             STATION_NAME  \
# 0                   Spire - Montgomery Operations Center
# 1                                    PS Energy - Atlanta
# 2           Metropolitan Atlanta Rapid Transit Authority
# 3                                  United Parcel Service
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
veh_petrol_df= veh_petrol_df.drop(columns=["STATION_NAME","STREET_ADDRESS", "DATE_LAST_CONFIRMED", "UPDATED_AT", 
                              "OPEN_DATE",
                             "GROUPS_WITH_ACCESS_CODE_FRENCH"], axis=1)
veh_petrol_df
# Out:
#                X          Y  OBJECTID FUEL_TYPE_CODE  \
# 0     -86.267021  32.367916         1            CNG
# 1     -84.398837  33.745843         2            CNG
# 2     -84.367461  33.821911         3            CNG
# 3     -84.543822  33.760256         4            CNG
# 4     -95.435385  29.779918         5            CNG
# ...          ...        ...       ...            ...
# 59922 -90.718917  41.439327     59923             BD
# 59923 -90.435422  40.663268     59924             BD
# 59924 -88.860665  42.274948     59925             BD
# 59925 -88.723836  41.923353     59926             BD
# 59926 -89.630156  42.275947     59927             BD
#
#                                  INTERSECTION_DIRECTIONS        CITY STATE  \
# 0                                                    NaN  Montgomery    AL
# 1      From I-7585 N, exit 91 to Central Ave, left on...     Atlanta    GA
# 2                                                    NaN     Atlanta    GA
# ...
