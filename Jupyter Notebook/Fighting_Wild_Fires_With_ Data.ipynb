# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import pandas as pd
import tensorflow as tf


cali_fire_df = pd.read_csv('California_Fire_Incidents.csv')
cali_fire_df
# Out:
#       AcresBurned  Active                                          AdminUnit  \
# 0        257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1         30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2         27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3         27440.0   False                              Tahoe National Forest
# 4         24251.0   False                       Ventura County Fire/CAL FIRE
# ...           ...     ...                                                ...
# 1631          9.0   False                   CAL FIRE / Riverside County Fire
# 1632          2.0   False                  CAL FIRE Nevada-Yuba-Placer Unit
# 1633          NaN   False               Yolo County Fire Protection District
# 1634          NaN   False                   Camp Pendleton Marine Corps Base
# 1635          NaN   False                           Bureau of Indian Affairs
#
#       AirTankers  ArchiveYear  CalFireIncident  \
# 0            NaN         2013             True
# 1            NaN         2013             True
# 2            NaN         2013             True
# 3            NaN         2013            False
# 4            NaN         2013             True
# ...          ...          ...              ...
# 1631         NaN         2019             True
# 1632         NaN         2019             True
# 1633         NaN         2019            False
# 1634         NaN         2019            False
# 1635         NaN         2019            False
#
#                                CanonicalUrl  \
# 0            /incidents/2013/8/17/rim-fire/
# 1     /incidents/2013/5/30/powerhouse-fire/
# 2       /incidents/2013/7/15/mountain-fire/
# 3       /incidents/2013/8/10/american-fire/
# 4         /incidents/2013/5/2/springs-fire/
# ...                                     ...
# 1631      /incidents/2019/10/10/eagle-fire/
# 1632        /incidents/2019/6/28/long-fire/
# 1633      /incidents/2019/11/25/cashe-fire/
# 1634        /incidents/2019/10/22/oak-fire/
# 1635    /incidents/2019/10/14/johnson-fire/
#
#                                      ConditionStatement ControlStatement  \
# 0                                                   NaN              NaN
# 1                                                   NaN              NaN
# 2                                                   NaN              NaN
# 3                                                   NaN              NaN
# 4     Acreage has been reduced based upon more accur...              NaN
# ...                                                 ...              ...
# 1631                                                NaN              NaN
# 1632                                                NaN              NaN
# 1633                                                NaN              NaN
# 1634                                                NaN              NaN
# 1635  As of 10:00 p.m. on 10/16, the fire is 90% con...              NaN
#
#          Counties  ...                                     SearchKeywords  \
# 0        Tuolumne  ...  Rim Fire, Stanislaus National Forest, Yosemite...
# 1     Los Angeles  ...  Powerhouse Fire, May 2013, June 2013, Angeles ...
# 2       Riverside  ...  Mountain Fire, July 2013, Highway 243, Highway...
# 3          Placer  ...  American Fire, August 2013, Deadwood Ridge, Fo...
# 4         Ventura  ...  Springs Fire, May 2013, Highway 101, Camarillo...
# ...           ...  ...                                                ...
# 1631    Riverside  ...                                                NaN
# 1632       Nevada  ...                                                NaN
# 1633         Yolo  ...                                                NaN
# 1634    San Diego  ...                                                NaN
# 1635    Riverside  ...                                                NaN
#
#                    Started     Status  StructuresDamaged StructuresDestroyed  \
# 0     2013-08-17T15:25:00Z  Finalized                NaN                 NaN
# 1     2013-05-30T15:28:00Z  Finalized                NaN                 NaN
# 2     2013-07-15T13:43:00Z  Finalized                NaN                 NaN
# 3     2013-08-10T16:30:00Z  Finalized                NaN                 NaN
# 4     2013-05-02T07:01:00Z  Finalized                6.0                10.0
# ...                    ...        ...                ...                 ...
# 1631  2019-10-10T12:08:00Z  Finalized                NaN                 NaN
# 1632  2019-06-28T15:03:04Z  Finalized                NaN                 NaN
# 1633  2019-11-25T12:02:02Z  Finalized                NaN                 NaN
# 1634  2019-10-22T19:20:44Z  Finalized                NaN                 NaN
# 1635  2019-10-14T15:32:20Z   Inactive                NaN                 NaN
#
#       StructuresEvacuated  StructuresThreatened  \
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 1631                  NaN                   NaN
# 1632                  NaN                   NaN
# 1633                  NaN                   NaN
# 1634                  NaN                   NaN
# 1635                  NaN                   NaN
#
#                                   UniqueId                   Updated  \
# 0     5fb18d4d-213f-4d83-a179-daaf11939e78      2013-09-06T18:30:00Z
# 1     bf37805e-1cc2-4208-9972-753e47874c87      2013-06-08T18:30:00Z
# 2     a3149fec-4d48-427c-8b2c-59e8b79d59db      2013-07-30T18:00:00Z
# 3     8213f5c7-34fa-403b-a4bc-da2ace6e6625      2013-08-30T08:00:00Z
# 4     46731fb8-3350-4920-bdf7-910ac0eb715c      2013-05-11T06:30:00Z
# ...                                    ...                       ...
# 1631  6e93b252-99a3-4214-9921-238373b17535  2019-10-10T18:11:59.733Z
# 1632  b38c0563-b321-431b-9174-6336c5a0d449  2019-06-30T15:52:01.023Z
# 1633  9c26f915-1b33-422d-b30a-9eb4da6fd729   2019-12-03T16:35:20.93Z
# 1634  7264a106-e0f4-41de-8fd0-3f9110431e28   2019-11-21T12:21:28.58Z
# 1635  8bf75401-999f-42bd-8c0a-8db508591545   2019-10-30T10:14:19.58Z
#
#       WaterTenders
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4             11.0
# ...            ...
# 1631           NaN
# 1632           NaN
# 1633           NaN
# 1634           NaN
# 1635           NaN
#
# [1636 rows x 40 columns]

# %%
cali_fire_df.isna().sum()
# Out:
# AcresBurned                3
# Active                     0
# AdminUnit                  0
# AirTankers              1608
# ArchiveYear                0
# CalFireIncident            0
# CanonicalUrl               0
# ConditionStatement      1352
# ControlStatement        1525
# Counties                   0
# CountyIds                  0
# CrewsInvolved           1465
# Dozers                  1513
# Engines                 1445
# Extinguished              59
# Fatalities              1615
# Featured                   0
# Final                      0
# FuelType                1624
# Helicopters             1552
# Injuries                1516
# Latitude                   0
# Location                   0
# Longitude                  0
# MajorIncident              0
# Name                       0
# PercentContained           3
# PersonnelInvolved       1432
# Public                     0
# SearchDescription         17
# SearchKeywords           203
# Started                    0
# Status                     0
# StructuresDamaged       1569
# StructuresDestroyed     1461
# StructuresEvacuated     1636
# StructuresThreatened    1606
# UniqueId                   0
# Updated                    0
# WaterTenders            1490
# dtype: int64

# %%
cali_fire_df.dropna(thresh=len(cali_fire_df)*0.9, axis='columns').head()
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    ArchiveYear  CalFireIncident                           CanonicalUrl  \
# 0         2013             True         /incidents/2013/8/17/rim-fire/
# 1         2013             True  /incidents/2013/5/30/powerhouse-fire/
# 2         2013             True    /incidents/2013/7/15/mountain-fire/
# 3         2013            False    /incidents/2013/8/10/american-fire/
# 4         2013             True      /incidents/2013/5/2/springs-fire/
#
#       Counties CountyIds          Extinguished  Featured  ...   Longitude  \
# 0     Tuolumne        55  2013-09-06T18:30:00Z     False  ... -120.086000
# 1  Los Angeles        19  2013-06-08T18:30:00Z     False  ... -118.423176
# 2    Riverside        33  2013-07-30T18:00:00Z     False  ... -116.728850
# 3       Placer        31  2013-08-30T08:00:00Z     False  ... -120.650000
# 4      Ventura        56  2013-05-11T06:30:00Z     False  ...    0.000000
#
#    MajorIncident             Name  PercentContained  Public  \
# 0          False         Rim Fire             100.0    True
# 1          False  Powerhouse Fire             100.0    True
# 2          False    Mountain Fire             100.0    True
# 3          False    American Fire             100.0    True
# 4           True     Springs Fire             100.0    True
#
#                                    SearchDescription               Started  \
# 0  The Rim Fire was east of Groveland along Highw...  2013-08-17T15:25:00Z
# 1  The Powerhouse Fire burned in May and June 201...  2013-05-30T15:28:00Z
# 2  The Mountain Fire burned in July 2013 off High...  2013-07-15T13:43:00Z
# 3  The American Fire burned in August 2013 off De...  2013-08-10T16:30:00Z
# 4  The Springs Fire burned in May 2013, Southboun...  2013-05-02T07:01:00Z
#
#       Status                              UniqueId               Updated
# 0  Finalized  5fb18d4d-213f-4d83-a179-daaf11939e78  2013-09-06T18:30:00Z
# 1  Finalized  bf37805e-1cc2-4208-9972-753e47874c87  2013-06-08T18:30:00Z
# 2  Finalized  a3149fec-4d48-427c-8b2c-59e8b79d59db  2013-07-30T18:00:00Z
# 3  Finalized  8213f5c7-34fa-403b-a4bc-da2ace6e6625  2013-08-30T08:00:00Z
# 4  Finalized  46731fb8-3350-4920-bdf7-910ac0eb715c  2013-05-11T06:30:00Z
#
# [5 rows x 23 columns]
