# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import tensorflow as tf

# %%
# Load data
file_path = "usa_co2_temp_1800_2013.csv"
predict_temp_df = pd.read_csv(file_path)
predict_temp_df.head(10)
# Out:
#          country  year    co2  co2_per_capita  cement_co2  \
# 0  United States  1800  0.253           0.042         NaN
# 1  United States  1801  0.267           0.044         NaN
# 2  United States  1802  0.289           0.046         NaN
# 3  United States  1803  0.297           0.047         NaN
# 4  United States  1804  0.333           0.052         NaN
# 5  United States  1805  0.341           0.052         NaN
# 6  United States  1806  0.333           0.050         NaN
# 7  United States  1807  0.377           0.055         NaN
# 8  United States  1808  0.392           0.056         NaN
# 9  United States  1809  0.403           0.057         NaN
#
#    cement_co2_per_capita  coal_co2  coal_co2_per_capita  flaring_co2  gas_co2  \
# 0                    NaN     0.253                0.042          NaN      NaN
# 1                    NaN     0.267                0.044          NaN      NaN
# 2                    NaN     0.289                0.046          NaN      NaN
# 3                    NaN     0.297                0.047          NaN      NaN
# 4                    NaN     0.333                0.052          NaN      NaN
# 5                    NaN     0.341                0.052          NaN      NaN
# 6                    NaN     0.333                0.050          NaN      NaN
# 7                    NaN     0.377                0.055          NaN      NaN
# 8                    NaN     0.392                0.056          NaN      NaN
# 9                    NaN     0.403                0.057          NaN      NaN
#
#    ...  co2_per_gdp  methane  methane_per_capita  nitrous_oxide  \
# 0  ...          NaN      NaN                 NaN            NaN
# 1  ...          NaN      NaN                 NaN            NaN
# 2  ...          NaN      NaN                 NaN            NaN
# 3  ...          NaN      NaN                 NaN            NaN
# 4  ...          NaN      NaN                 NaN            NaN
# 5  ...          NaN      NaN                 NaN            NaN
# 6  ...          NaN      NaN                 NaN            NaN
# 7  ...          NaN      NaN                 NaN            NaN
# 8  ...          NaN      NaN                 NaN            NaN
# 9  ...          NaN      NaN                 NaN            NaN
#
#    nitrous_oxide_per_capita  population  gdp  energy_per_gdp  Avg Temperature  \
# 0                       NaN     6000000  NaN             NaN        12.377868
# 1                       NaN     6113782  NaN             NaN        12.681863
# 2                       NaN     6229723  NaN             NaN        12.859703
# 3                       NaN     6347862  NaN             NaN        12.692603
# 4                       NaN     6468241  NaN             NaN        12.576432
# 5                       NaN     6590903  NaN             NaN        12.599647
# 6                       NaN     6715891  NaN             NaN        12.048269
# 7                       NaN     6843249  NaN             NaN        11.884543
# 8                       NaN     6973023  NaN             NaN        11.949342
# 9                       NaN     7105258  NaN             NaN        11.329233
#
#    Avg Temperature Uncertainty
# 0                     3.205628
# 1                     2.895417
# 2                     3.065703
# 3                     3.065032
# 4                     3.379515
# 5                     3.106361
# 6                     3.067562
# 7                     3.124994
# 8                     3.235417
# 9                     3.485137
#
# [10 rows x 24 columns]
